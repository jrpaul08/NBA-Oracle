# %% [markdown]
# # Imports

# %%
import os
from bs4 import BeautifulSoup 
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeout
import time
import asyncio

# %%
# !playwright install

# %% [markdown]
# # Global Variables

# %%
SEASONS = list(range(2021, 2024))

# %%
DATA_DIR = 'data'
STANDINGS_DIR = os.path.join(DATA_DIR, 'standings')
SCORES_DIR = os.path.join(DATA_DIR, 'scores')

# %%
# Ensure directories exist
os.makedirs(STANDINGS_DIR, exist_ok=True)
os.makedirs(SCORES_DIR, exist_ok=True)

# %% [markdown]
# # Webscraping Functions

# %% [markdown]
# ## Get HTML Function

# %%
import asyncio
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeout

async def get_html(url, selector, sleep=5, retries=3):
    """
    Fetches the HTML of a given URL, waiting for a specific selector to load.
    Retries if timeouts occur.
    """
    html = None

    for i in range(retries + 1):
        # Non-blocking sleep before retrying (instead of time.sleep)
        await asyncio.sleep(sleep)

        try:
            async with async_playwright() as p:
                # Launch browser (use headless=False for debugging)
                browser = await p.chromium.launch(headless=True)

                # New page instance
                page = await browser.new_page()

                # Go to URL with a generous timeout
                await page.goto(url, timeout=30000)

                # Wait explicitly for the selector to appear
                await page.wait_for_selector(selector, timeout=20000)

                # Optional: print page title for debugging
                try:
                    print(f"Loaded: {await page.title()}")
                except Exception:
                    pass

                # Extract HTML once selector is available
                html = await page.inner_html(selector)

                # Close browser cleanly
                await browser.close()

        except PlaywrightTimeout:
            print(f"Timeout error on {url} (attempt {i+1}/{retries+1})")
            continue  # Try again
        except Exception as e:
            print(f"Error on {url}: {e}")
            continue
        else:
            # Successfully retrieved HTML
            break

    return html

# %% [markdown]
# ## Webscraping Season info Function

# %%
async def scrape_season(season):
    url = f"https://www.basketball-reference.com/leagues/NBA_{season}_games.html"
    html = await get_html(url, '#content .filter')

    soup = BeautifulSoup(html)
    links = soup.find_all('a')
    hrefs = [l['href'] for l in links]
    standings_urls = [f"https://www.basketball-reference.com{link}" for link in hrefs]

    for url in standings_urls:
        filename = url.split('/')[-1]
        save_path = os.path.join(STANDINGS_DIR, filename)
        if os.path.exists(save_path):
            print(f"Skipping {url} because it already exists")
            continue
        html = await get_html(url, '#all_schedule')
        if not html:
            print(f"No HTML for {url}; skipping")
            continue
        with open(save_path, 'w') as f:
            f.write(html)


    return standings_urls

# %%
for season in SEASONS:
    await scrape_season(season)

# %%
standings_files = os.listdir(STANDINGS_DIR)

# %%
async def scrape_game(standings_file):
    with open(standings_file, 'r') as f:
        html = f.read()

    soup = BeautifulSoup(html)
    links = soup.find_all('a')
    hrefs = [link.get("href") for link in links]
    box_scores = [href for href in hrefs if href and "boxscore" in href and ".html" in href]
    box_scores = [f"https://www.basketball-reference.com{link}" for link in box_scores]

    for url in box_scores:
        save_path = os.path.join(SCORES_DIR, url.split('/')[-1])
        if os.path.exists(save_path):
            continue
        html = await get_html(url, "#content")
        if not html:
            continue
        with open(save_path, "w+") as f:
            f.write(html)

# %%
for f in standings_files:
    filepath = os.path.join(STANDINGS_DIR, f)
    await scrape_game(filepath)
# Out:
# Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
#
 2020 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202001280CHO.html (attempt 1/4)
# Loaded: Knicks vs Hornets, January 28, 2020 | Basketball-Reference.com
# Loaded: Warriors vs 76ers, January 28, 2020 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202001280CLE.html (attempt 1/4)
# Loaded: Pelicans vs Cavaliers, January 28, 2020 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202001280TOR.html (attempt 1/4)
# Loaded: Hawks vs Raptors, January 28, 2020 | Basketball-Reference.com
# Loaded: Nuggets vs Grizzlies, January 28, 2020 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202001280MIA.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202001280MIA.html (attempt 2/4)
# Loaded: Celtics vs Heat, January 28, 2020 | Basketball-Reference.com
# Loaded: Wizards vs Bucks, January 28, 2020 | Basketball-Reference.com
# Loaded: Suns vs Mavericks, January 28, 2020 | Basketball-Reference.com
# Loaded: Bulls vs Pacers, January 29, 2020 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202001290BRK.html (attempt 1/4)
# Loaded: Pistons vs Nets, January 29, 2020 | Basketball-Reference.com
# Loaded: Grizzlies vs Knicks, January 29, 2020 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202001290SAS.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202001290SAS.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202001290SAS.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202001290SAS.html (attempt 4/4)
# Loaded: Rockets vs Trail Blazers, January 29, 2020 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202001290SAC.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202001290SAC.html (attempt 2/4)
# Loaded: Thunder vs Kings, January 29, 2020 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202001300CLE.html (attempt 1/4)
# ...
# Loaded: Nets vs Trail Blazers, November 17, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211170SAC.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211170SAC.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211170SAC.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211170SAC.html (attempt 4/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211170LAC.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211170LAC.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211170LAC.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211170LAC.html (attempt 4/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180WAS.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180WAS.html (attempt 2/4)
# Loaded: Heat vs Wizards, November 18, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211180CLE.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180CLE.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180CLE.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180CLE.html (attempt 4/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180PHI.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180PHI.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180PHI.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180PHI.html (attempt 4/4)
# Loaded: Magic vs Bulls, November 18, 2022 | Basketball-Reference.com
# Loaded: Pacers vs Rockets, November 18, 2022 | Basketball-Reference.com
# Loaded: Thunder vs Grizzlies, November 18, 2022 | Basketball-Reference.com
# Loaded: Nuggets vs Mavericks, November 18, 2022 | Basketball-Reference.com
# Loaded: Celtics vs Pelicans, November 18, 2022 | Basketball-Reference.com
# Loaded: Suns vs Jazz, November 18, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211180GSW.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180GSW.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180GSW.html (attempt 3/4)
# Loaded: Knicks vs Warriors, November 18, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211180LAL.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211180LAL.html (attempt 2/4)
# Loaded: Pistons vs Lakers, November 18, 2022 | Basketball-Reference.com
# Loaded: Raptors vs Hawks, November 19, 2022 | Basketball-Reference.com
# Loaded: Magic vs Pacers, November 19, 2022 | Basketball-Reference.com
# Loaded: Timberwolves vs 76ers, November 19, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211190POR.html (attempt 1/4)
# Loaded: Jazz vs Trail Blazers, November 19, 2022 | Basketball-Reference.com
# Loaded: Spurs vs Clippers, November 19, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211200PHO.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211200PHO.html (attempt 2/4)
# Loaded: Knicks vs Suns, November 20, 2022 | Basketball-Reference.com
# Loaded: Pistons vs Kings, November 20, 2022 | Basketball-Reference.com
# Loaded: Hornets vs Wizards, November 20, 2022 | Basketball-Reference.com
# Loaded: Grizzlies vs Nets, November 20, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211200CLE.html (attempt 1/4)
# Loaded: Heat vs Cavaliers, November 20, 2022 | Basketball-Reference.com
# Loaded: Warriors vs Rockets, November 20, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211200DAL.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211200DAL.html (attempt 2/4)
# Loaded: Nuggets vs Mavericks, November 20, 2022 | Basketball-Reference.com
# Loaded: Spurs vs Lakers, November 20, 2022 | Basketball-Reference.com
# Loaded: Hawks vs Cavaliers, November 21, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211210IND.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211210IND.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211210IND.html (attempt 3/4)
# Loaded: Magic vs Pacers, November 21, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211210CHI.html (attempt 1/4)
# Loaded: Celtics vs Bulls, November 21, 2022 | Basketball-Reference.com
# Loaded: Trail Blazers vs Bucks, November 21, 2022 | Basketball-Reference.com
# Loaded: Heat vs Timberwolves, November 21, 2022 | Basketball-Reference.com
# Loaded: Warriors vs Pelicans, November 21, 2022 | Basketball-Reference.com
# Loaded: Knicks vs Thunder, November 21, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211210LAC.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211210LAC.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211210LAC.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211210LAC.html (attempt 4/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211220PHI.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211220PHI.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211220PHI.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211220PHI.html (attempt 4/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211220MEM.html (attempt 1/4)
# Loaded: Kings vs Grizzlies, November 22, 2022 | Basketball-Reference.com
# Loaded: Pistons vs Nuggets, November 22, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211220PHO.html (attempt 1/4)
# Loaded: Lakers vs Suns, November 22, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211230CHO.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230CHO.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230CHO.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230CHO.html (attempt 4/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230CLE.html (attempt 1/4)
# Loaded: Trail Blazers vs Cavaliers, November 23, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211230IND.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230IND.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230IND.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230IND.html (attempt 4/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230ATL.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230ATL.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230ATL.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230ATL.html (attempt 4/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230BOS.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230BOS.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230BOS.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230BOS.html (attempt 4/4)
# Loaded: Wizards vs Heat, November 23, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211230TOR.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230TOR.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230TOR.html (attempt 3/4)
# Loaded: Nets vs Raptors, November 23, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211230MIL.html (attempt 1/4)
# Loaded: Bulls vs Bucks, November 23, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211230OKC.html (attempt 1/4)
# Loaded: Nuggets vs Thunder, November 23, 2022 | Basketball-Reference.com
# Loaded: Pelicans vs Spurs, November 23, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211230UTA.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230UTA.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211230UTA.html (attempt 3/4)
# Loaded: Pistons vs Jazz, November 23, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211230GSW.html (attempt 1/4)
# Loaded: Clippers vs Warriors, November 23, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211250CHO.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211250CHO.html (attempt 2/4)
# Loaded: Timberwolves vs Hornets, November 25, 2022 | Basketball-Reference.com
# Loaded: 76ers vs Magic, November 25, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211250NYK.html (attempt 1/4)
# Loaded: Trail Blazers vs Knicks, November 25, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211250BOS.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211250BOS.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211250BOS.html (attempt 3/4)
# Loaded: Kings vs Celtics, November 25, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211250HOU.html (attempt 1/4)
# Loaded: Hawks vs Rockets, November 25, 2022 | Basketball-Reference.com
# Timeout error on https://www.basketball-reference.com/boxscores/202211250IND.html (attempt 1/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211250IND.html (attempt 2/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211250IND.html (attempt 3/4)
# Timeout error on https://www.basketball-reference.com/boxscores/202211250IND.html (attempt 4/4)
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 for f in standings_files:
#       2     filepath = os.path.join(STANDINGS_DIR, f)
# ----> 3     await scrape_game(filepath)
#
# Cell In[14], line 15, in scrape_game(standings_file)
#      13 if os.path.exists(save_path):
#      14     continue
# ---> 15 html = await get_html(url, "#content")
#      16 if not html:
#      17     continue
#
# Cell In[17], line 24, in get_html(url, selector, sleep, retries)
#      21 page = await browser.new_page()
#      23 # Go to URL with a generous timeout
# ---> 24 await page.goto(url, timeout=30000)
#      26 # Wait explicitly for the selector to appear
#      27 await page.wait_for_selector(selector, timeout=20000)
#
# File ~/Coding/BasketballPredictions/myenv/lib/python3.9/site-packages/playwright/async_api/_generated.py:8992, in Page.goto(self, url, timeout, wait_until, referer)
#    8931 async def goto(
#    8932     self,
#    8933     url: str,
#    (...)
#    8939     referer: typing.Optional[str] = None,
#    8940 ) -> typing.Optional["Response"]:
#    8941     """Page.goto
#    8942
#    8943     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)
#    8988     Union[Response, None]
#    8989     """
#    8991     return mapping.from_impl_nullable(
# -> 8992         await self._impl_obj.goto(
#    8993             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8994         )
#    8995     )
#
# File ~/Coding/BasketballPredictions/myenv/lib/python3.9/site-packages/playwright/_impl/_page.py:556, in Page.goto(self, url, timeout, waitUntil, referer)
#     549 async def goto(
#     550     self,
#     551     url: str,
#    (...)
#     554     referer: str = None,
#     555 ) -> Optional[Response]:
# --> 556     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File ~/Coding/BasketballPredictions/myenv/lib/python3.9/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)
#     148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File ~/Coding/BasketballPredictions/myenv/lib/python3.9/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)
#      67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File ~/Coding/BasketballPredictions/myenv/lib/python3.9/site-packages/playwright/_impl/_connection.py:556, in Connection.wrap_api_call(self, cb, is_internal, title)
#     554 self._api_zone.set(parsed_st)
#     555 try:
# --> 556     return await cb()
#     557 except Exception as error:
#     558     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#
# File ~/Coding/BasketballPredictions/myenv/lib/python3.9/site-packages/playwright/_impl/_connection.py:123, in Channel._inner_send(self, method, timeout_calculator, params, return_as_dict)
#     119     raise error
#     120 callback = self._connection._send_message_to_server(
#     121     self._object, method, _augment_params(params, timeout_calculator)
#     122 )
# --> 123 done, _ = await asyncio.wait(
#     124     {
#     125         self._connection._transport.on_error_future,
#     126         callback.future,
#     127     },
#     128     return_when=asyncio.FIRST_COMPLETED,
#     129 )
#     130 if not callback.future.done():
#     131     callback.future.cancel()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/tasks.py:413, in wait(fs, loop, timeout, return_when)
#     406     warnings.warn("The explicit passing of coroutine objects to "
#     407                   "asyncio.wait() is deprecated since Python 3.8, and "
#     408                   "scheduled for removal in Python 3.11.",
#     409                   DeprecationWarning, stacklevel=2)
#     411 fs = {ensure_future(f, loop=loop) for f in fs}
# --> 413 return await _wait(fs, timeout, return_when, loop)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/tasks.py:529, in _wait(fs, timeout, return_when, loop)
#     526     f.add_done_callback(_on_completion)
#     528 try:
# --> 529     await waiter
#     530 finally:
#     531     if timeout_handle is not None:
#
# CancelledError:
